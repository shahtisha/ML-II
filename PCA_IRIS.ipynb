# %% [markdown]
# <a href="https://colab.research.google.com/github/shahtisha/ML-II/blob/main/PCA_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
df = datasets.load_iris()
x = df.data
y = df.target
target_names = df.target_names
print("X:",x[0])
scaler = MinMaxScaler()
scaler.fit(x)
x_scaled = scaler.transform(x)
# Out:
# X: [5.1 3.5 1.4 0.2]

# %%
def plotting(x, title, vtitle):
  plt.figure()
  for i, target_name in zip([0,1,2], target_names):
    plt.scatter(x[y==i, 0], x[y==i, 1], label=target_name)
    plt.title(title)
    plt.xlabel(vtitle + "1")
    plt.ylabel(vtitle + "2")
    plt.legend(loc = 'upper right')
    plt.show()

# %%
pca = PCA()
pca_transformed = pca.fit_transform(x_scaled)
print("pca transformed: ",pca_transformed)
plotting(pca_transformed[:, :2], 'PCA', 'PC')
# Out:
# pca transformed:  [[-6.30702931e-01  1.07577910e-01 -1.87190977e-02 -7.30694581e-03]
#  [-6.22904943e-01 -1.04259833e-01 -4.91420253e-02 -3.23589895e-02]
#  [-6.69520395e-01 -5.14170597e-02  1.96441728e-02 -7.43434730e-03]
#  [-6.54152759e-01 -1.02884871e-01  2.32185515e-02  2.01144295e-02]
#  [-6.48788056e-01  1.33487576e-01  1.51155243e-02  1.17862966e-02]
#  [-5.35272778e-01  2.89615724e-01  2.54378874e-02  2.83282860e-04]
#  [-6.56537790e-01  1.07244911e-02  9.18347789e-02  1.48777630e-02]
#  [-6.25780499e-01  5.71335411e-02 -1.40277647e-02  6.97998828e-03]
#  [-6.75643504e-01 -2.00703283e-01  3.59520802e-02  8.90276963e-03]
#  [-6.45644619e-01 -6.72080097e-02 -6.17055833e-02  9.01397899e-03]
#  [-5.97408238e-01  2.17151953e-01 -5.12740810e-02 -6.15445290e-03]
#  [-6.38943190e-01  3.25988375e-02  2.44981902e-02  4.03601648e-02]
#  [-6.61612593e-01 -1.15605495e-01 -5.47803418e-02 -3.22277227e-03]
#  [-7.51967943e-01 -1.71313322e-01  4.76777938e-02  7.28753435e-03]
# ...
